# %% [markdown]
# # Simple plot
# ---
#
# Exemplo baseado em https://matplotlib.org/gallery/lines_bars_and_markers/simple_plot.html

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# Data for plotting
t = np.arange(0.0, 2.0, 0.01) # eixo x
s = 1 + np.sin(2 * np.pi * t) # eixo y

# Note that using plt.subplots below is equivalent to using
# fig = plt.figure and then ax = fig.add_subplot(111)
fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

plt.show()
